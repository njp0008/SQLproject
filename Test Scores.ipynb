# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.max_rows = 1000

# %%
students_df = pd.read_csv(r'C:\Users\Nick\Downloads\students_performance.csv')

# %%
students_df #displaying the entire dataset to reference
# Out:
#      gender   groups parental_level_of_education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# 5    female  group B          associate's degree      standard
# 6    female  group B                some college      standard
# 7      male  group B                some college  free/reduced
# 8      male  group D                 high school  free/reduced
# 9    female  group B                 high school  free/reduced
# 10     male  group C          associate's degree      standard
# 11     male  group D          associate's degree      standard
# 12   female  group B                 high school      standard
# 13     male  group A                some college      standard
# ...

# %%
students_df.describe() #summary statistics
#the overall mean in scores is very similar to the results I recieved from MySQL!
# Out:
#         math_score  reading_score  writing_score
# count  1000.000000    1000.000000    1000.000000
# mean     66.100000      69.169000      68.054000
# std      15.169183      14.600192      15.195657
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      57.750000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
students_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
students_df['gender'].value_counts()
#how many students are male and female - used .value_counts() method
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
students_df.sort_values(by='parental_level_of_education', ascending=False) 
#sorting by parental_level_of_education
# Out:
#      gender   groups parental_level_of_education         lunch  \
# 546  female  group A            some high school      standard
# 265    male  group D            some high school  free/reduced
# 223    male  group D            some high school      standard
# 222  female  group C            some high school  free/reduced
# 722  female  group B            some high school  free/reduced
# 126    male  group B            some high school      standard
# 545    male  group E            some high school  free/reduced
# 829    male  group B            some high school      standard
# 828  female  group D            some high school  free/reduced
# 827  female  group C            some high school      standard
# 131    male  group C            some high school  free/reduced
# 550    male  group C            some high school  free/reduced
# 841    male  group C            some high school      standard
# 824  female  group C            some high school  free/reduced
# ...

# %%
y = np.array([64.0779, 66.5349, 64.5047])
mylabels = ["math average", "reading average", "writing average"]
plt.title("Average Scores of Students Who Didn't Take a Test Preperation Course")
plt.pie(y, labels = mylabels)
#using numpy created an array using the average scores that were queried from MySQL database. 
#then created a piechart to show the averages. Since the scores are so close, the slight differerences aren't noticable.
# Out:
# ([<matplotlib.patches.Wedge at 0x1693ef521c0>,
# ...
#  [Text(0.5646776593483834, 0.9440016636811777, 'math average'),
#   Text(-1.0999740279801185, 0.007558952916493438, 'reading average'),
#   Text(0.5581774481404547, -0.9478596607026856, 'writing average')])

# %%
students_df['parental_level_of_education'].value_counts().plot(kind='bar', title='Parental Level of Education')
#created a bar graph detailing how many students
# Out:
# <AxesSubplot:title={'center':'Parental Level of Education'}>

# %%
students_df[['parental_level_of_education']].value_counts()
#totals
# Out:
# parental_level_of_education
# some college                   226
# associate's degree             222
# high school                    196
# some high school               179
# bachelor's degree              118
# master's degree                 59
# dtype: int64

# %%
score_filter = students_df[['math_score', 'writing_score', 'reading_score']]
print(score_filter)
# Out:
#      math_score  writing_score  reading_score
# 0            72             74             72
# 1            80             88             90
# 2            90             93             95
# 3            47             44             57
# 4            76             75             78
# 5            71             78             83
# 6            88             92             95
# 7            40             39             43
# 8            64             67             64
# 9            38             50             60
# 10           58             52             54
# 11           40             43             52
# 12           65             73             81
# 13           78             70             72
# 14           50             58             53
# 15           69             78             75
# 16           88             86             89
# 17           18             28             32
# 18           46             46             42
# ...
